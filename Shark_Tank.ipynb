# %% [markdown]
# <a id="1"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:30px;font-family:Georgia;text-align:center;display:fill;border-radius:5px;background-color:#254E58;overflow:hidden"><b>✨ Shark Tank Data Analysis ✨</b></div>
# <b>Shark Tank</b>: is a popular television show where aspiring entrepreneurs pitch their business ideas to a panel of wealthy investors, known as "sharks," with the goal of securing investment deals. The show provides a unique platform for entrepreneurs to showcase their innovative products, services, and business concepts to potential investors and a broad audience. Analyzing the data generated from Shark Tank episodes can offer valuable insights into entrepreneurial trends, investor preferences, and the dynamics of successful pitch presentations.

# %% [markdown]
# <a id="1"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:30px;font-family:Georgia;text-align:center;display:fill;border-radius:5px;background-color:#254E58;overflow:hidden"><b>✨ Importing Libraries✨</b></div>

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly as pl
import cufflinks as cf
from plotly.offline import iplot
pl.offline.init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
# ...

# %% [markdown]
# <a id="1"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:30px;font-family:Georgia;text-align:center;display:fill;border-radius:5px;background-color:#254E58;overflow:hidden"><b>⏳Loading Dataset⏳</b></div>

# %%
df=pd.read_csv(r"C:\Users\Avnish_kumar\Apython\Shark Tank\Shark Tank India Dataset.csv")
df
# Out:
#      episode_number  pitch_number           brand_name  \
# 0                 1             1  BluePine Industries
# 1                 1             2        Booz scooters
# 2                 1             3  Heart up my Sleeves
# 3                 2             4           Tagz Foods
# 4                 2             5       Head and Heart
# ..              ...           ...                  ...
# 112              34           113        Green Protein
# 113              34           114              On2Cook
# 114              35           115        Jain Shikanji
# 115              35           116                Woloo
# 116              35           117         Elcare India
#
#                                               idea  deal  pitcher_ask_amount  \
# 0                                     Frozen Momos     1                50.0
# 1    Renting e-bike for mobility in private spaces     1                40.0
# ...

# %% [markdown]
# <a id="1"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:35px;font-family:Verdana;text-align:center;display:fill;border-radius:5px;background-color:#254E58;overflow:hidden"><b>🧠 Basic Understanding of Data 🧠</b></div>

# %% [markdown]
# ### 1. Cheking Dimension of Dataset.

# %%
df.shape
# Out:
# (117, 28)

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=brown>📊 Inference:</font></h3>
#
# * There are total **117 Records/Rows** in the dataset.
# * There are total **28 Features/columns** in the dataset.

# %% [markdown]
# ### 2 Generating Basic Information About Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   episode_number         117 non-null    int64
#  1   pitch_number           117 non-null    int64
#  2   brand_name             117 non-null    object
#  3   idea                   117 non-null    object
#  4   deal                   117 non-null    int64
#  5   pitcher_ask_amount     117 non-null    float64
#  6   ask_equity             117 non-null    float64
#  7   ask_valuation          117 non-null    float64
#  8   deal_amount            117 non-null    float64
#  9   deal_equity            117 non-null    float64
#  10  deal_valuation         117 non-null    float64
#  11  ashneer_present        117 non-null    int64
#  12  anupam_present         117 non-null    int64
#  13  aman_present           117 non-null    int64
# ...

# %% [markdown]
# ###  3 Computing missing values

# %%
df.isnull().sum()
# Out:
# episode_number           0
# pitch_number             0
# brand_name               0
# idea                     0
# deal                     0
# pitcher_ask_amount       0
# ask_equity               0
# ask_valuation            0
# deal_amount              0
# deal_equity              0
# deal_valuation           0
# ashneer_present          0
# anupam_present           0
# aman_present             0
# namita_present           0
# vineeta_present          0
# peyush_present           0
# ghazal_present           0
# ashneer_deal             0
# anupam_deal              0
# aman_deal                0
# namita_deal              0
# vineeta_deal             0
# peyush_deal              0
# ghazal_deal              0
# total_sharks_invested    0
# amount_per_shark         0
# equity_per_shark         0
# dtype: int64

# %% [markdown]
# <b>No Null Value found</b>

# %% [markdown]
# ## 3. Checking Data-Types of Features.

# %%
df.dtypes
# Out:
# episode_number             int64
# pitch_number               int64
# brand_name                object
# idea                      object
# deal                       int64
# pitcher_ask_amount       float64
# ask_equity               float64
# ask_valuation            float64
# deal_amount              float64
# deal_equity              float64
# deal_valuation           float64
# ashneer_present            int64
# anupam_present             int64
# aman_present               int64
# namita_present             int64
# vineeta_present            int64
# peyush_present             int64
# ghazal_present             int64
# ashneer_deal               int64
# anupam_deal                int64
# aman_deal                  int64
# namita_deal                int64
# vineeta_deal               int64
# peyush_deal                int64
# ghazal_deal                int64
# total_sharks_invested      int64
# amount_per_shark         float64
# equity_per_shark         float64
# dtype: object

# %% [markdown]
# <a id="1"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:30px;font-family:Georgia;text-align:center;display:fill;border-radius:5px;background-color:#254E58;overflow:hidden"><b>✨Exploratory Data Analysis(EDA)  ✨</b></div>

# %% [markdown]
# ### 1 How many total deal done in whole season ?

# %%
deal=df[df['deal']==1].shape[0]
notdeal=df[df['deal']==0].shape[0]
print('Succesful Deal =',deal)
print('Un Succesful Deal=',notdeal)
# Out:
# Succesful Deal = 65
# Un Succesful Deal= 52

# %%
de=df['deal'].value_counts().values
de
e=df['deal'].value_counts().index
e,de
# Out:
# (Int64Index([1, 0], dtype='int64'), array([65, 52], dtype=int64))

# %%
plt.pie(de,labels=e,autopct='%0.2f%%');

# %%
sns.set(style='darkgrid')

# %% [markdown]
# ###  2 Most Dealing Episodes

# %%
m=df.groupby('episode_number')['deal'].agg(['sum']).sort_values(by='sum',ascending=False).reset_index()
m
# Out:
#     episode_number  sum
# 0                1    3
# 1               15    3
# 2               21    3
# 3               33    3
# 4                8    3
# 5               10    3
# 6               17    3
# 7               16    3
# 8               13    3
# 9               25    2
# 10              24    2
# 11              28    2
# 12              20    2
# 13              26    2
# 14              27    2
# 15              12    2
# 16              11    2
# 17               9    2
# 18               6    2
# 19               4    2
# 20               3    2
# 21              31    1
# 22              30    1
# 23              29    1
# 24              34    1
# 25              32    1
# 26              18    1
# 27              23    1
# 28              22    1
# 29              19    1
# 30               2    1
# 31              14    1
# 32               7    1
# 33               5    1
# 34              35    1

# %%
sns.catplot(x='deal',y='episode_number',data=df,hue='deal',kind='swarm');

# %% [markdown]
# ### 2 bar plot to show most dealing episode

# %%
plt.figure(figsize=(11,6))
sns.barplot(x='episode_number',y='sum',data=m);

# %% [markdown]
# ### 3 Over all Most expensive Dealing episode

# %%
ex=df.groupby('episode_number')['deal_amount'].agg(['sum']).reset_index()
ex
# Out:
#     episode_number        sum
# 0                1  140.00000
# 1                2   70.00000
# 2                3   95.00000
# 3                4  125.00000
# 4                5  100.00000
# 5                6  150.00000
# 6                7  100.00000
# 7                8  136.00000
# 8                9  100.00000
# 9               10   85.00000
# 10              11   80.00000
# 11              12  115.00000
# 12              13  255.00000
# 13              14  100.00000
# 14              15  125.00005
# 15              16  170.00000
# 16              17  280.00000
# 17              18    1.00000
# 18              19   60.00000
# 19              20  140.00000
# 20              21  160.00000
# 21              22   60.00000
# 22              23   50.00000
# 23              24   60.00000
# 24              25  150.00000
# 25              26  115.00000
# 26              27  100.00101
# 27              28  150.00000
# 28              29   75.00000
# 29              30   80.00000
# ...

# %%
plt.figure(figsize=(10,7),dpi=400)
sns.barplot(x='episode_number',y='sum',data=ex);

# %% [markdown]
# ### 4 Deal in which all sharks in

# %%
df[df['total_sharks_invested']==5]
# Out:
#     episode_number  pitch_number             brand_name                 idea  \
# 15               6            16            Skippi Pops             Ice-Pops
# 49              17            50  Find Your Kicks India       Sneaker Resale
# 63              20            64               IN A CAN        Can Cocktails
# 79              25            80    Sunfox Technologies  Portable ECG Device
#
#     deal  pitcher_ask_amount  ask_equity  ask_valuation  deal_amount  \
# 15     1                45.0         5.0          900.0        100.0
# 49     1                50.0        10.0          500.0         50.0
# 63     1                50.0         2.0         2500.0        100.0
# 79     1               100.0         2.0         5000.0        100.0
#
#     deal_equity  ...  ashneer_deal  anupam_deal  aman_deal  namita_deal  \
# 15         15.0  ...             1            1          1            1
# 49         25.0  ...             1            1          1            1
# ...

# %% [markdown]
# ### 5 Deal in which all sharks doesn't Bargain

# %%
df[(df['pitcher_ask_amount']==df['deal_amount'])]
# Out:
#      episode_number  pitch_number                      brand_name  \
# 1                 1             2                   Booz scooters
# 2                 1             3             Heart up my Sleeves
# 3                 2             4                      Tagz Foods
# 7                 3             8                       Peeschute
# 9                 4            10                           Cosiq
# 11                4            12                          Bummer
# 12                5            13                     Revamp Moto
# 16                6            17                    Menstrupedia
# 18                7            19              Raising Superstars
# 21                8            22                    Beyond Snack
# 22                8            23  Vivalyf Innovations- Easy Life
# 23                8            24                   Motion Breeze
# 24                9            25                           Altor
# ...

# %% [markdown]
# ### 6 The ideas in which all sharks doesn't  invest

# %%
invest=df[df['deal_amount']==0][['idea','episode_number']]
invest
# Out:
#                                                  idea  episode_number
# 4                            Brain Development Course               2
# 5                                             Tourism               2
# 6                             Food Freshness Detector               3
# 10                                             Pickle               4
# 13               Restaurant serving 80 types of Maggi               5
# 14                                Belly Button Shaper               5
# 17                         Pollution Resistant Fabric               6
# 19               Gadgets for visually impaired people               7
# 20                        Kheer in variety of flavors               7
# 26                                       Healthy Oils               9
# 30                                    Fiber Ice Cream              11
# 34                                      Indian Sweets              12
# ...

# %%
# plt.figure(figsize=(115,6))
invest.plot(kind='bar',x='idea',y='episode_number',figsize=(11,4));

# %% [markdown]
# ### 7 Created a function that show the Equity and Amount per shark

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   episode_number         117 non-null    int64
#  1   pitch_number           117 non-null    int64
#  2   brand_name             117 non-null    object
#  3   idea                   117 non-null    object
#  4   deal                   117 non-null    int64
#  5   pitcher_ask_amount     117 non-null    float64
#  6   ask_equity             117 non-null    float64
#  7   ask_valuation          117 non-null    float64
#  8   deal_amount            117 non-null    float64
#  9   deal_equity            117 non-null    float64
#  10  deal_valuation         117 non-null    float64
#  11  ashneer_present        117 non-null    int64
#  12  anupam_present         117 non-null    int64
#  13  aman_present           117 non-null    int64
# ...

# %%
p=df.iloc[:,11:18].columns
p
# Out:
# Index(['ashneer_present', 'anupam_present', 'aman_present', 'namita_present',
#        'vineeta_present', 'peyush_present', 'ghazal_present'],
#       dtype='object')

# %%
# Out:
# Index(['ashneer_deal', 'anupam_deal', 'aman_deal', 'namita_deal',
#        'vineeta_deal', 'peyush_deal', 'ghazal_deal'],
#       dtype='object')

# %% [markdown]
# ### Deal of shark with team and single deal

# %%
df[(df['ashneer_deal']==1) & (df['deal']==1) & (df['total_sharks_invested']>=2)]
# Out:
#      episode_number  pitch_number             brand_name  \
# 0                 1             1    BluePine Industries
# 1                 1             2          Booz scooters
# 15                6            16            Skippi Pops
# 21                8            22           Beyond Snack
# 29               10            30              EventBeep
# 38               13            39        The Yarn Bazaar
# 45               16            46           Bamboo India
# 49               17            50  Find Your Kicks India
# 50               17            51          Aas Vidyalaya
# 58               19            59                WeSTOCK
# 63               20            64               IN A CAN
# 64               21            65             Get a Whey
# 67               22            68         Hair Originals
# 108              33           109             Tweek Labs
# 109              33           110                 Proxgy
# ...

# %% [markdown]
# ### Number of deal of each shark with each shark  and amount per shark and toal amount and equety

# %%
ashneer=df[(df['deal']==1) & (df['ashneer_deal'])]
ashneer
# Out:
#      episode_number  pitch_number             brand_name  \
# 0                 1             1    BluePine Industries
# 1                 1             2          Booz scooters
# 3                 2             4             Tagz Foods
# 15                6            16            Skippi Pops
# 21                8            22           Beyond Snack
# 23                8            24          Motion Breeze
# 29               10            30              EventBeep
# 38               13            39        The Yarn Bazaar
# 45               16            46           Bamboo India
# 49               17            50  Find Your Kicks India
# 50               17            51          Aas Vidyalaya
# 55               18            56                   Otua
# 58               19            59                WeSTOCK
# 63               20            64               IN A CAN
# 64               21            65             Get a Whey
# ...

# %%
d=df.iloc[:,18:25].columns
d
# Out:
# Index(['ashneer_deal', 'anupam_deal', 'aman_deal', 'namita_deal',
#        'vineeta_deal', 'peyush_deal', 'ghazal_deal'],
#       dtype='object')

# %%
def all_shark(data):
    for i in d:
        deal=data[['amount_per_shark','equity_per_shark']][data[i]==1]
        print('ashneer Deal with',i[:-5],'is ',len(deal))
        print(deal)

# %%
all_shark(ashneer)
# Out:
# ashneer Deal with ashneer is  20
#      amount_per_shark  equity_per_shark
# 0           25.000000          5.333333
# 1           20.000000         25.000000
# 3           70.000000          2.750000
# 15          20.000000          3.000000
# 21          25.000000          1.250000
# 23          30.000000          6.000000
# 29          10.000000          1.000000
# 38          25.000000          2.500000
# 45          25.000000          1.750000
# 49          10.000000          5.000000
# 50          50.000000          5.000000
# 55           1.000000          1.000000
# 58          15.000000          2.500000
# 63          20.000000          2.000000
# 64          33.333333          5.000000
# 67          20.000000          1.333333
# 108         20.000000          3.333333
# 109          5.000000          5.000000
# 110         10.000000          5.000000
# 114         10.000000          7.500000
# ashneer Deal with anupam is  8
#      amount_per_shark  equity_per_shark
# ...

# %%
anupam=df[(df['anupam_deal']==1) & (df['deal']==1)]
anupam
# Out:
#      episode_number  pitch_number                      brand_name  \
# 2                 1             3             Heart up my Sleeves
# 9                 4            10                           Cosiq
# 12                5            13                     Revamp Moto
# 15                6            16                     Skippi Pops
# 22                8            23  Vivalyf Innovations- Easy Life
# 28               10            29                        Meatyour
# 31               11            32        ARRCOAT Surface Textures
# 35               12            36                            LOKA
# 36               13            37                           Annie
# 37               13            38                       Caragreen
# 38               13            39                 The Yarn Bazaar
# 44               15            45                         Cocofit
# 45               16            46                    Bamboo India
# ...

# %%
all_shark(anupam)
# Out:
# ashneer Deal with ashneer is  8
#      amount_per_shark  equity_per_shark
# 15               20.0          3.000000
# 38               25.0          2.500000
# 45               25.0          1.750000
# 49               10.0          5.000000
# 63               20.0          2.000000
# 67               20.0          1.333333
# 108              20.0          3.333333
# 114              10.0          7.500000
# ashneer Deal with anupam is  24
#      amount_per_shark  equity_per_shark
# 2           12.500000         15.000000
# 9           25.000000         12.500000
# 12          50.000000          0.750000
# 15          20.000000          3.000000
# 22          28.000000         16.650000
# 28          10.000000          6.666667
# 31          50.000000         15.000000
# 35          13.333333          8.000000
# 36          35.000000          1.000000
# 37          25.000000         10.000000
# 38          25.000000          2.500000
# 44           0.000017          1.666667
# ...

# %%
for i in d:
    a=i[:-5]
    amount=a['amount_per_shark'].sum()
    equamt=a[:-5]['equity_per_shark'].sum()
    print(amount,'Total amount of shark and total equity=',equamt)

# %% [markdown]
# ###  Similarly deal of Each shark and with amount and equity can be visulize
