# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly as pl
import cufflinks as cf
from plotly.offline import iplot
pl.offline.init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
# ...

# %%
df=pd.read_csv(r"C:\Users\Avnish_kumar\Downloads\Super Market-20230823T042105Z-001\Super Market\supermarket_sales - Sheet1.csv")

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# ...

# %%
obj=[i for i in df if df[i].dtypes=='object']
z=df[obj]
z
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line       Date   Time      Payment
# 0         Health and beauty   1/5/2019  13:08      Ewallet
# 1    Electronic accessories   3/8/2019  10:29         Cash
# 2        Home and lifestyle   3/3/2019  13:23  Credit card
# ...

# %%
a=[i for i in df if df[i].dtypes!='object']
num=df[a]
num
# Out:
#      Unit price  Quantity   Tax 5%      Total    cogs  \
# 0         74.69         7  26.1415   548.9715  522.83
# 1         15.28         5   3.8200    80.2200   76.40
# 2         46.33         7  16.2155   340.5255  324.31
# 3         58.22         8  23.2880   489.0480  465.76
# 4         86.31         7  30.2085   634.3785  604.17
# ..          ...       ...      ...        ...     ...
# 995       40.35         1   2.0175    42.3675   40.35
# 996       97.38        10  48.6900  1022.4900  973.80
# 997       31.84         1   1.5920    33.4320   31.84
# 998       65.82         1   3.2910    69.1110   65.82
# 999       88.34         7  30.9190   649.2990  618.38
#
#      gross margin percentage  gross income  Rating
# 0                   4.761905       26.1415     9.1
# 1                   4.761905        3.8200     9.6
# 2                   4.761905       16.2155     7.4
# 3                   4.761905       23.2880     8.4
# 4                   4.761905       30.2085     5.3
# ...

# %%
for i in obj:
    if i!='Invoice ID' and i!='Date' and i!='Time' :
        print(i,'......',df[i].nunique(),'.....',df[i].unique())
        print(i,'......',df[i].value_counts())
# Out:
# Branch ...... 3 ..... ['A' 'C' 'B']
# Branch ...... A    340
# B    332
# C    328
# Name: Branch, dtype: int64
# City ...... 3 ..... ['Yangon' 'Naypyitaw' 'Mandalay']
# City ...... Yangon       340
# Mandalay     332
# Naypyitaw    328
# Name: City, dtype: int64
# Customer type ...... 2 ..... ['Member' 'Normal']
# Customer type ...... Member    501
# Normal    499
# Name: Customer type, dtype: int64
# Gender ...... 2 ..... ['Female' 'Male']
# Gender ...... Female    501
# Male      499
# Name: Gender, dtype: int64
# Product line ...... 6 ..... ['Health and beauty' 'Electronic accessories' 'Home and lifestyle'
#  'Sports and travel' 'Food and beverages' 'Fashion accessories']
# Product line ...... Fashion accessories       178
# Food and beverages        174
# Electronic accessories    170
# Sports and travel         166
# Home and lifestyle        160
# Health and beauty         152
# Name: Product line, dtype: int64
# Payment ...... 3 ..... ['Ewallet' 'Cash' 'Credit card']
# ...

# %%
plt.figure(figsize=(22,6))
c=1
for i in z:
    if i!='Invoice ID' and i!='Date' and i!='Time' and i!='Product line':
        plt.subplot(1,5,c)
        sns.countplot(data=z,x=z[i])
        plt.xticks(rotation=90,fontsize=15)
        c+=1
plt.show()
sns.countplot(x=z['Product line'],data=z)
plt.xticks(rotation=90,fontsize=15);

# %%
k=df.groupby(['Product line','Branch'])['gross income'].agg(['count','mean']).reset_index()
k
# Out:
#               Product line Branch  count       mean
# 0   Electronic accessories      A     60  14.537392
# 1   Electronic accessories      B     55  14.763155
# 2   Electronic accessories      C     55  16.423355
# 3      Fashion accessories      A     51  15.249775
# 4      Fashion accessories      B     62  12.606234
# 5      Fashion accessories      C     65  15.794923
# 6       Food and beverages      A     58  14.091216
# 7       Food and beverages      B     50  14.490370
# 8       Food and beverages      C     66  17.147803
# 9        Health and beauty      A     47  12.763681
# 10       Health and beauty      B     53  17.952075
# 11       Health and beauty      C     52  15.215500
# 12      Home and lifestyle      A     65  16.422854
# 13      Home and lifestyle      B     50  16.713490
# 14      Home and lifestyle      C     45  14.704289
# 15       Sports and travel      A     59  15.635754
# 16       Sports and travel      B     62  15.351919
# ...

# %%
sns.barplot(x='Product line',y='mean',data=k)
plt.xticks(rotation=70);

# %%
sns.countplot(x='Branch',data=k);

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
a=df.groupby('Branch')['gross income'].agg(['sum']).reset_index()
a
# Out:
#   Branch        sum
# 0      A  5057.1605
# 1      B  5057.0320
# 2      C  5265.1765

# %%
d=df.groupby('Gender')['gross income'].agg(['sum']).reset_index()
d
# Out:
#    Gender       sum
# 0  Female  7994.425
# 1    Male  7384.944

# %%
plt.figure(dpi=150)
plt.pie('sum',labels='Branch',autopct='%0.2f%%',radius=.8,data=a);

# %%
plt.figure(dpi=150,figsize=(3,2))
plt.pie('sum',labels='Gender',autopct='%0.2f%%',data=d);

# %%
p=df.groupby('Product line')['gross income'].agg(['sum']).reset_index()
p
# Out:
#              Product line        sum
# 0  Electronic accessories  2587.5015
# 1     Fashion accessories  2585.9950
# 2      Food and beverages  2673.5640
# 3       Health and beauty  2342.5590
# 4      Home and lifestyle  2564.8530
# 5       Sports and travel  2624.8965

# %%
plt.figure(dpi=600)
plt.pie('sum',labels='Product line',autopct='%0.2f%%',data=p);

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
l=[1,5,8,7,99,2,555]
largest=a
for i in l:
    if largest is a or largest <i:
        largest = i
print(largest)
# Out:
# 555

# %%
l=[1,5,8,7,99,2,555]
largest=a
for i in l:
    if largest is a or largest >i:
        largest = i
print(largest)
# Out:
# 1

# %%
e=df.groupby('City')['gross income'].agg(["sum"]).reset_index()
e
# Out:
#         City        sum
# 0   Mandalay  5057.0320
# 1  Naypyitaw  5265.1765
# 2     Yangon  5057.1605

# %%
sns.barplot(x=e['City'],y=e['sum'],data=e);

# %%
df['Date']=pd.to_datetime(df['Date'])
df.dtypes
# Out:
# Invoice ID                         object
# Branch                             object
# City                               object
# Customer type                      object
# Gender                             object
# Product line                       object
# Unit price                        float64
# Quantity                            int64
# Tax 5%                            float64
# Total                             float64
# Date                       datetime64[ns]
# Time                               object
# Payment                            object
# cogs                              float64
# gross margin percentage           float64
# gross income                      float64
# Rating                            float64
# dtype: object

# %%
da=df['Date'].dt.month_name().unique()
da
# Out:
# array(['January', 'March', 'February'], dtype=object)

# %%
df['Month']=df['Date'].dt.month_name()
df['Month']
# Out:
# 0       January
# 1         March
# 2         March
# 3       January
# 4      February
#          ...
# 995     January
# 996       March
# 997    February
# 998    February
# 999    February
# Name: Month, Length: 1000, dtype: object

# %%
ms=df.groupby('Month')['gross income'].agg(['sum']).reset_index()
ms
# Out:
#       Month       sum
# 0  February  4629.494
# 1   January  5537.708
# 2     March  5212.167

# %%
sns.barplot(x='Month',y='sum',data=ms);

# %%
df['Date'].dt.day_name().unique()
# Out:
# array(['Saturday', 'Friday', 'Sunday', 'Monday', 'Thursday', 'Wednesday',
#        'Tuesday'], dtype=object)

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2019-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2019-01-27
# 4       Sports and travel       86.31         7  30.2085  634.3785 2019-02-08
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df.groupby('Product line')['Quantity'].sum().iplot(kind='bar',color='green');
# Out:
# <div>                            <div id="1c6d5032-55fa-498b-bad5-c63550796366" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
m=df.groupby('Customer type')['gross income'].agg(['sum']).reset_index()
m
# Out:
#   Customer type       sum
# 0        Member  7820.164
# 1        Normal  7559.205

# %%
plt.pie('sum',labels='Customer type',data=m,autopct='%0.2f%%');

# %%
df['Days']=df['Date'].dt.day_name()

# %%
i=df.groupby(['Month','Days'])['gross income'].agg(['sum']).sort_values(by='sum',ascending=False).reset_index()
i
# Out:
#        Month       Days        sum
# 0      March   Saturday  1227.1870
# 1    January    Tuesday  1009.7385
# 2    January   Thursday   924.5895
# 3    January   Saturday   861.6040
# 4    January  Wednesday   848.0180
# 5      March    Tuesday   838.6350
# 6   February     Friday   800.1090
# 7   February     Sunday   791.9515
# 8      March     Friday   757.3600
# 9    January     Sunday   683.6550
# 10   January     Monday   675.8415
# 11     March  Wednesday   643.6775
# 12     March     Sunday   641.4360
# 13  February     Monday   632.6150
# 14  February   Thursday   627.2885
# 15     March   Thursday   607.6100
# 16  February    Tuesday   603.1620
# 17  February  Wednesday   590.7395
# 18  February   Saturday   583.6285
# 19   January     Friday   534.2615
# 20     March     Monday   496.2615

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2019-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2019-01-27
# 4       Sports and travel       86.31         7  30.2085  634.3785 2019-02-08
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
c=df[df['Branch']=='C']
c
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 5    699-14-3026      C  Naypyitaw        Normal    Male
# 7    315-22-5665      C  Naypyitaw        Normal  Female
# 20   300-71-4605      C  Naypyitaw        Member    Male
# 34   183-56-6882      C  Naypyitaw        Member  Female
# ..           ...    ...        ...           ...     ...
# 983  148-41-7930      C  Naypyitaw        Normal    Male
# 984  189-40-5216      C  Naypyitaw        Normal    Male
# 988  267-62-7380      C  Naypyitaw        Member    Male
# 994  652-49-6720      C  Naypyitaw        Member  Female
# 995  233-67-5758      C  Naypyitaw        Normal    Male
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 1    Electronic accessories       15.28         5   3.8200   80.2200
# 5    Electronic accessories       85.39         7  29.8865  627.6165
# 7        Home and lifestyle       73.56        10  36.7800  772.3800
# ...

# %%
b=df[df['Branch']=='B']
b
# Out:
#       Invoice ID Branch      City Customer type  Gender  \
# 9    692-92-5582      B  Mandalay        Member  Female
# 10   351-62-0822      B  Mandalay        Member  Female
# 11   529-56-3974      B  Mandalay        Member    Male
# 15   299-46-1805      B  Mandalay        Member  Female
# 19   319-50-3348      B  Mandalay        Normal  Female
# ..           ...    ...       ...           ...     ...
# 987  552-44-5977      B  Mandalay        Member    Male
# 989  430-53-4718      B  Mandalay        Member    Male
# 991  602-16-6955      B  Mandalay        Normal  Female
# 993  690-01-6631      B  Mandalay        Normal    Male
# 996  303-96-2227      B  Mandalay        Normal  Female
#
#                Product line  Unit price  Quantity  Tax 5%     Total  \
# 9        Food and beverages       54.84         3   8.226   172.746
# 10      Fashion accessories       14.48         4   2.896    60.816
# 11   Electronic accessories       25.51         4   5.102   107.142
# ...

# %%
a=df[df['Branch']=='A']
a
# Out:
#       Invoice ID Branch    City Customer type  Gender            Product line  \
# 0    750-67-8428      A  Yangon        Member  Female       Health and beauty
# 2    631-41-3108      A  Yangon        Normal    Male      Home and lifestyle
# 3    123-19-1176      A  Yangon        Member    Male       Health and beauty
# 4    373-73-7910      A  Yangon        Normal    Male       Sports and travel
# 6    355-53-5943      A  Yangon        Member  Female  Electronic accessories
# ..           ...    ...     ...           ...     ...                     ...
# 990  886-18-2897      A  Yangon        Normal  Female      Food and beverages
# 992  745-74-0715      A  Yangon        Normal    Male  Electronic accessories
# 997  727-02-1313      A  Yangon        Member    Male      Food and beverages
# 998  347-56-2442      A  Yangon        Normal    Male      Home and lifestyle
# 999  849-09-3807      A  Yangon        Member  Female     Fashion accessories
#
# ...

# %%
cum=c.groupby('Customer type')['gross income'].agg(['sum']).reset_index()
cum
# Out:
#   Customer type        sum
# 0        Member  2708.6325
# 1        Normal  2556.5440

# %%
sns.barplot(x='Customer type',y='sum',data=cum);

# %%
R=c.groupby('Customer type')['Rating'].agg(['mean']).reset_index()
R
# Out:
#   Customer type      mean
# 0        Member  7.048521
# 1        Normal  7.098742

# %%
sns.barplot(x='Customer type',y='mean',data=R);

# %%
sns.relplot(x='Total',y='gross income',data=a);
